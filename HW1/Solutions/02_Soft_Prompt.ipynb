# %% [markdown]
# # Homework 1 Part 2
#
# ## Course Name: Large Language Models
# #### Lecturers: Dr. Soleimani, Dr. Rohban, Dr. Asgari
#
# ---
#
# #### Notebooks Supervised By: MohammadAli SadraeiJavaheri
# #### Notebooks Prepared By: Zeinab Sadat Taghavi, Hamed Jamshidian, Seyed Mohammad Reza Modarres
#
# **Contact**: Ask your questions in Quera
#
# ---
#
# ### Instructions:
# - Complete all exercises presented in this notebook.
# - Ensure you run each cell after you've entered your solution.
# - After completing the exercises, save the notebook and <font color='red'>follow the submission guidelines provided in the PDF.</font>
#
#
# ---
#
# **Note**: Replace the placeholders (between `## Your code begins ##` and `## Your code ends ##`) with the appropriate details.

# %% [markdown]
# # Introduction

# %% [markdown]
# <b> What are soft prompts? </b>
# <br>
# soft prompts can be described as a concept that involves incorporating vectors into an input sequence and then fine-tuning these vectors while keeping the rest of the pre-trained model's components unchanged. We deonte our input with $X$ and we denote $P$ as the matrix of these soft prompt vectors.
# <br>
# <div>
# <img src="https://drive.google.com/uc?id=1aGI6FgvK3udOmHnWt1dCvC7lh6e9C2Oe" width="50%"/>
# </div>
#
# Read More :
# <br>[Youtube : PEFT and Soft Prompt](https://www.youtube.com/watch?v=8uy_WII76L0)
# <br>[Blog : What are soft prompts?](https://softwaremind.com/blog/how-and-why-soft-promps-are-slowly-replacing-text-prompts/)

# %% [markdown]
# ### Requirements

# %%
# %%capture
! pip install datasets transformers

# %% [markdown]
# ### Imports

# %%
from tqdm.notebook import tqdm
from IPython import display

import numpy as np
import pandas as pd

from sklearn.metrics import accuracy_score

import torch
import torch.nn as nn

from datasets import load_dataset
from transformers import T5TokenizerFast, T5ForConditionalGeneration, DataCollatorForSeq2Seq

# %% [markdown]
# ### Constants

# %% [markdown]
# ### Base Model Selection
# We will use `t5-small` as our base model from Hugging Face ([HF_Link](https://huggingface.co/t5-small)). For our tuning, we intend to utilize `10` soft prompt tokens ([HF_Link](https://huggingface.co/docs/peft/conceptual_guides/prompting), [Paper_Link](https://arxiv.org/abs/2104.08691)).

# %%
#####################################
###### DO NOT CHANGE THIS CELL ######
#####################################

BASE_MODEL_NAME = 't5-small'
N_SOFT_PROMPT_TOKENS = 10

BATCH_SIZE = 32
LEARNING_RATE = 0.1
EPOCHS = 10

DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Dataset

# %% [markdown]
# ### Load dataset

# %% [markdown]
# `imdb` dataset is a famouns NLP for binary sentiment dataset. Each row of data is either `negative` or `positive` ([HF_Link](https://huggingface.co/datasets/imdb)).

# %%
dataset = load_dataset('imdb')
dataset.pop('unsupervised')
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
# })

# %% [markdown]
# ### Define related functions

# %% [markdown]
# Because `T5` model is a sequence to sequence model we should map our labels to label_names before training and doing vice versa duing calculating metrics.
#
# The functions `id2label` and `label2id` are defined to do this.

# %%
def id2label(ids):
    label_names = ['negative', 'positive']
    return [label_names[id] for id in ids]

def label2id(labels):
    label_names_dict = {
        'negative': 0,
        'positive': 1
    }
    return [
        label_names_dict.get(label, 2)
        for label in labels
    ]

# %% [markdown]
# # Tokenizer

# %% [markdown]
# ### Load tokenizer

# %%
tokenizer = T5TokenizerFast.from_pretrained(BASE_MODEL_NAME)

# %% [markdown]
# ### Process dataset using tokenizer

# %% [markdown]
# In this step we will getting our dataset ready for training.
#
# We preprocess tokenize our `text` and `label`.
#
# For easier prompt tuning we put placeholders by prepending multiple `pad_token` to our input. The count of this pad tokens is the same as `n_soft_prompt_tokens`.
#
# <font color='#73FF73'><b>You have to complete</b></font> `preprend_padding_token` <font color='#73FF73'><b>function.</b></font>
#
# Replace `None` with your code.

# %%
def preprocess_input(text):
    text = text.lower()
    text = text.replace('<br />', ' ')
    return text

def preprend_padding_token(text):
    n_soft_prompt_tokens = N_SOFT_PROMPT_TOKENS
    pad_token = tokenizer.pad_token

    ######### Your code begins #########
    prefix = pad_token * n_soft_prompt_tokens
    ######### Your code ends ###########

    return prefix + text

def map_function(row):
    processed_input = [
        preprend_padding_token(preprocess_input(text))
        for text in row['text']
    ]
    input_info = tokenizer(processed_input, truncation=True, max_length=256)
    output_info = tokenizer(id2label(row['label']))
    return {
        **input_info,
        'labels': output_info.input_ids
    }


dataset = dataset.map(map_function, batched=True)
dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])

# %% [markdown]
# # Model

# %% [markdown]
# ### Load model

# %%
model = T5ForConditionalGeneration.from_pretrained(BASE_MODEL_NAME)

# %% [markdown]
# ### Define prompt related layers

# %% [markdown]
# In this part we will define our prompt layer in `SimplePrompts`. It's a simple layer that only returns it's prompt matrix when called.
#
# `EmbeddingWrapper` is a layer that will replace original embedding layer of model and it functions as our injection into the model architecture.
#
# We use `sharif_llm` in our PEFT module name so we could keep it unfreeze during training.
#
# <font color='#73FF73'><b>You have to complete</b></font> `prompts_joiner` <font color='#73FF73'><b>function.</b></font>
#
# In this function prompts will concatenated to model input embeddings. But in `preprend_padding_token` we allready put some placeholders for prompts. We just need to replace it with real prompts.
#
# At first step you must repeat `prompts` in each batch_size and then remove placeholder embedings from `input_embedding` to calculate `non_place_holders`.

# %%
class SimplePrompts(nn.Module):
    def __init__(self, inital_values: torch.Tensor):
        super().__init__()
        self.n_tokens = inital_values.size(0)
        self.emb_dim = inital_values.size(1)
        self.prompt_emb = nn.parameter.Parameter(
            inital_values.detach().clone()
        )

    def forward(self):
        return self.prompt_emb

def prompts_joiner(prompts, input_embedding):
    # prompts.shape         = (n_tokens, emb_dim)
    # input_embedding.shape = (batch_size, n_tokens + seq_len, emb_dim)

    n_tokens = prompts.size(0)
    batch_size = input_embedding.size(0)
    ######### Your code begins #########
    prompts_batched = prompts.repeat(batch_size, 1, 1)
    non_place_holders = input_embedding[:, n_tokens:]
    ######### Your code ends ###########

    assert prompts_batched.shape == (batch_size, *prompts.shape)
    assert non_place_holders.shape[1] + n_tokens == input_embedding.shape[1]

    return torch.cat([prompts_batched, non_place_holders], dim=1)

class EmbeddingWrapper(nn.Module):
    def __init__(
        self,
        emb_layer: nn.Embedding,
        n_tokens: int,
        **kwargs
    ):
        super().__init__()
        self.emb_layer = emb_layer

        prompt_inital_values = self.emb_layer.weight[:n_tokens]

        self.sharif_llm_soft_prompts = SimplePrompts(inital_values=prompt_inital_values)

    def forward(self, tokens):
        prompts = self.sharif_llm_soft_prompts()
        input_embedding = self.emb_layer(tokens)
        return prompts_joiner(prompts, input_embedding)

# %% [markdown]
# ### Replace encoder's embedding layer with our layer

# %% [markdown]
# <font color='#73FF73'><b>You have to complete</b></font> `mutate_model` <font color='#73FF73'><b>function.</b></font>
#
# In this part we want to replace <b>model encoder embedding layer</b> with our wrapper.
#
# You must use `get_encoder`, `get_input_embeddings` to get model embedding layer and use `EmbeddingWrapper` to create new embedding layer.

# %%
def mutate_model(model, n_tokens):
    if hasattr(model, '_mutated'):
        print("Model already contains Soft Prompt layers! \n Try reloading the model.")
        return
    ######### Your code begins #########
    encoder = model.get_encoder()
    embedding_layer = encoder.get_input_embeddings()
    new_embedding_layer = EmbeddingWrapper(embedding_layer, n_tokens)
    ######### Your code ends ###########
    encoder.set_input_embeddings(new_embedding_layer)

    model._mutated = True

mutate_model(model, n_tokens=N_SOFT_PROMPT_TOKENS)

# %% [markdown]
# ### Freeze all model's weight except our PEFT module

# %% [markdown]
# In this part we will freeze entire model except `encoder.embed_tokens.sharif_llm_soft_prompts.prompt_emb`

# %%
def freeze_non_pefts(model, peft_key):
    print('Non freezed weights:')
    for param_name, weights in model.named_parameters():
        weights.requires_grad = peft_key in param_name
        if weights.requires_grad:
            print(param_name)

freeze_non_pefts(model, peft_key='sharif_llm')
# Out:
# Non freezed weights:
# encoder.embed_tokens.sharif_llm_soft_prompts.prompt_emb

# %% [markdown]
# # Train and evaluate

# %% [markdown]
# ### Define dataloaders

# %%
col_fn = DataCollatorForSeq2Seq(
    tokenizer, return_tensors='pt', padding='longest',
)

train_loader = torch.utils.data.DataLoader(
    dataset['train'],
    batch_size=BATCH_SIZE,
    collate_fn=col_fn,
    shuffle=True
)

test_loader = torch.utils.data.DataLoader(
    dataset['test'],
    batch_size=BATCH_SIZE,
    collate_fn=col_fn
)

# %% [markdown]
# ### Train functions

# %%
def train_loop(model, loader, optimizer):
    model.train()

    batch_losses = []

    for row in tqdm(loader, desc='Training:'):
        optimizer.zero_grad()

        out = model(**row.to(model.device))
        loss = out.loss

        batch_loss_value = loss.item()
        loss.backward()
        optimizer.step()

        batch_losses.append(batch_loss_value)

    loss_value = np.mean(batch_losses)
    return {'train_loss': loss_value}

def _predict(model, row):
    return model.generate(
        input_ids=row.input_ids,
        attention_mask=row.attention_mask,
        max_length=5
    )

def tokenizer_ids_to_label(all_input_ids):
    return tokenizer.batch_decode(all_input_ids, skip_special_tokens=True)

def valid_loop(model, loader, compute_metrics):
    model.eval()

    all_true = []
    all_pred = []

    with torch.no_grad():
        for row in tqdm(loader, desc='Validating:'):
            row.to(model.device)
            pred = _predict(model, row)

            all_true += row.labels.detach().cpu().tolist()
            all_pred += pred.detach().cpu().tolist()

    all_true = label2id(tokenizer_ids_to_label(all_true))
    all_pred = label2id(tokenizer_ids_to_label(all_pred))

    return {'valid_acc': compute_metrics(y_true=all_true, y_pred=all_pred)}

# %% [markdown]
# ### Define our optimizer and metric function

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE)
compute_metrics = accuracy_score

# %%
model.to(DEVICE)

all_results = []
for epoch in range(EPOCHS):
    epoch_results = {'epoch': epoch}

    epoch_results.update(
        train_loop(
            model=model,
            loader=train_loader,
            optimizer=optimizer,
        )
    )

    epoch_results.update(
        valid_loop(
            model=model,
            loader=test_loader,
            compute_metrics=compute_metrics,
        )
    )
    all_results.append(epoch_results)

    display.clear_output()
    display.display(pd.DataFrame(all_results).set_index('epoch'))
# Out:
#        train_loss  valid_acc
# epoch
# 0        1.379158    0.84912
# 1        0.201583    0.85592
# 2        0.190282    0.86160
# 3        0.187908    0.86516
# 4        0.186620    0.86348
# 5        0.185462    0.86456
# 6        0.185382    0.86580
# 7        0.181894    0.86348
# 8        0.188124    0.86324
# 9        0.184877    0.86412

# %% [markdown]
# ### Best Performance and number of parameters

# %% [markdown]
# You must report this number in you final report.

# %%
best_score = pd.DataFrame(all_results)['valid_acc'].max() * 100
total_params = sum(p.numel() for p in model.parameters())
print(f"Number of parameters: {total_params}")
print('Best model preformance is: %%%.1f' % best_score)
# Out:
# Number of parameters: 60511744
# Best model preformance is: %86.6

# %% [markdown]
# ### Save PEFT file

# %% [markdown]
# We expect you to <font color='#FF7373'>upload this file </font> with the rest of your files.

# %%
peft_dict = {
    key: val
    for (key, val) in model.state_dict().items()
    if 'sharif_llm' in key
}
torch.save(peft_dict, 'prompts.pt')

# %% [markdown]
# # Use external library

# %%
import locale

def getpreferredencoding(do_setlocale=True):
    return "UTF-8"

locale.getpreferredencoding = getpreferredencoding

# %%
# %pip install git+https://github.com/thunlp/OpenDelta.git
# Out:
# Collecting git+https://github.com/thunlp/OpenDelta.git
#   Cloning https://github.com/thunlp/OpenDelta.git to /tmp/pip-req-build-vizhb4kj
#   Running command git clone --filter=blob:none --quiet https://github.com/thunlp/OpenDelta.git /tmp/pip-req-build-vizhb4kj
#   Resolved https://github.com/thunlp/OpenDelta.git to commit 067eed2304cb1bdfe462094e42a37de4de98edff
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.8.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from opendelta==0.3.2) (1.11.0)
# Requirement already satisfied: transformers>=4.10.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from opendelta==0.3.2) (4.35.0)
# Requirement already satisfied: datasets>=1.17.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from opendelta==0.3.2) (2.14.6)
# Requirement already satisfied: sentencepiece>=0.1.96 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from opendelta==0.3.2) (0.1.99)
# Requirement already satisfied: tqdm>=4.62.2 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from opendelta==0.3.2) (4.65.0)
# Requirement already satisfied: decorator in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from opendelta==0.3.2) (5.1.1)
# Requirement already satisfied: rich in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from opendelta==0.3.2) (13.4.2)
# Requirement already satisfied: web.py in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from opendelta==0.3.2) (0.62)
# Requirement already satisfied: gitpython in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from opendelta==0.3.2) (3.1.40)
# Requirement already satisfied: scipy in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from opendelta==0.3.2) (1.11.1)
# Requirement already satisfied: scikit-learn in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from opendelta==0.3.2) (1.3.0)
# Requirement already satisfied: delta_center_client==0.0.4 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from opendelta==0.3.2) (0.0.4)
# Requirement already satisfied: bigmodelvis in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from opendelta==0.3.2) (0.0.1)
# Requirement already satisfied: oss2==2.15.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from delta_center_client==0.0.4->opendelta==0.3.2) (2.15.0)
# Requirement already satisfied: yacs>=0.1.6 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from delta_center_client==0.0.4->opendelta==0.3.2) (0.1.8)
# Requirement already satisfied: requests!=2.9.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2) (2.31.0)
# Requirement already satisfied: crcmod>=1.7 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2) (1.7)
# Requirement already satisfied: pycryptodome>=3.4.7 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2) (3.19.0)
# Requirement already satisfied: aliyun-python-sdk-kms>=2.4.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2) (2.16.2)
# Requirement already satisfied: aliyun-python-sdk-core>=2.13.12 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2) (2.14.0)
# Requirement already satisfied: six in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2) (1.16.0)
# Requirement already satisfied: numpy>=1.17 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from datasets>=1.17.0->opendelta==0.3.2) (1.26.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from datasets>=1.17.0->opendelta==0.3.2) (14.0.1)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from datasets>=1.17.0->opendelta==0.3.2) (0.3.7)
# Requirement already satisfied: pandas in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from datasets>=1.17.0->opendelta==0.3.2) (1.4.2)
# Requirement already satisfied: xxhash in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from datasets>=1.17.0->opendelta==0.3.2) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from datasets>=1.17.0->opendelta==0.3.2) (0.70.15)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from datasets>=1.17.0->opendelta==0.3.2) (2023.10.0)
# Requirement already satisfied: aiohttp in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from datasets>=1.17.0->opendelta==0.3.2) (3.8.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from datasets>=1.17.0->opendelta==0.3.2) (0.17.3)
# Requirement already satisfied: packaging in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from datasets>=1.17.0->opendelta==0.3.2) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from datasets>=1.17.0->opendelta==0.3.2) (6.0)
# Requirement already satisfied: typing_extensions in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from torch>=1.8.0->opendelta==0.3.2) (4.7.1)
# Requirement already satisfied: filelock in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from transformers>=4.10.0->opendelta==0.3.2) (3.13.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from transformers>=4.10.0->opendelta==0.3.2) (2023.10.3)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from transformers>=4.10.0->opendelta==0.3.2) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from transformers>=4.10.0->opendelta==0.3.2) (0.4.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from gitpython->opendelta==0.3.2) (4.0.11)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from rich->opendelta==0.3.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from rich->opendelta==0.3.2) (2.15.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-learn->opendelta==0.3.2) (1.3.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-learn->opendelta==0.3.2) (3.2.0)
# Requirement already satisfied: cheroot in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from web.py->opendelta==0.3.2) (10.0.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aiohttp->datasets>=1.17.0->opendelta==0.3.2) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aiohttp->datasets>=1.17.0->opendelta==0.3.2) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aiohttp->datasets>=1.17.0->opendelta==0.3.2) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aiohttp->datasets>=1.17.0->opendelta==0.3.2) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aiohttp->datasets>=1.17.0->opendelta==0.3.2) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aiohttp->datasets>=1.17.0->opendelta==0.3.2) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aiohttp->datasets>=1.17.0->opendelta==0.3.2) (1.3.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython->opendelta==0.3.2) (5.0.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->opendelta==0.3.2) (0.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests!=2.9.0->oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests!=2.9.0->oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests!=2.9.0->oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2) (2023.7.22)
# Requirement already satisfied: more-itertools>=2.6 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from cheroot->web.py->opendelta==0.3.2) (10.1.0)
# Requirement already satisfied: jaraco.functools in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from cheroot->web.py->opendelta==0.3.2) (4.0.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from pandas->datasets>=1.17.0->opendelta==0.3.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from pandas->datasets>=1.17.0->opendelta==0.3.2) (2023.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.9.3 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aliyun-python-sdk-core>=2.13.12->oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2) (0.10.0)
# Requirement already satisfied: cryptography>=2.6.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aliyun-python-sdk-core>=2.13.12->oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2) (36.0.2)
# Requirement already satisfied: cffi>=1.12 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2) (1.15.1)
# Requirement already satisfied: pycparser in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Use `OpenDelta` library to do the same thing. [link](https://opendelta.readthedocs.io/en/latest/modules/deltas.html)
#
# For hyperparameters, test with `N_SOFT_PROMPT_TOKENS=1` and `N_SOFT_PROMPT_TOKENS=10` and report them in your report.

# %% [markdown]
# ### Load The Saved Model

# %%
import torch
from transformers import T5ForConditionalGeneration

model = T5ForConditionalGeneration.from_pretrained(BASE_MODEL_NAME)
tokenizer = T5TokenizerFast.from_pretrained(BASE_MODEL_NAME)

# %%
def train_model(_model):
  _model = _model.to(DEVICE)
  all_results = []
  for epoch in range(EPOCHS):
      epoch_results = {'epoch': epoch}

      epoch_results.update(
          train_loop(
              model=_model,
              loader=train_loader,
              optimizer=optimizer,
          )
      )

      epoch_results.update(
          valid_loop(
              model=_model,
              loader=test_loader,
              compute_metrics=compute_metrics,
          )
      )
      all_results.append(epoch_results)

      display.clear_output()
      display.display(pd.DataFrame(all_results).set_index('epoch'))
  return all_results

# %% [markdown]
# ### Fine-Tuning With N_SOFT_PROMPTS = 10

# %%
from opendelta import SoftPromptModel

soft_prompt_model = SoftPromptModel(backbone_model=model, soft_token_num=N_SOFT_PROMPT_TOKENS)

soft_prompt_model = soft_prompt_model.to(DEVICE)


optimizer = torch.optim.AdamW(soft_prompt_model.parameters(), lr=LEARNING_RATE)
compute_metrics = accuracy_score

# %%
soft_prompt_model.freeze_module(exclude=['deltas'])

soft_prompt_model.log()
# Out:
# root
# ├── shared(Embedding),lm_head(Linear) weight:[32128, 512]
# ├── encoder (T5Stack)
# │   ├── embed_tokens (Embedding) weight:[32128, 512]
# │   ├── block (ModuleList)
# │   │   ├── 0 (T5Block)
# │   │   │   └── layer (ModuleList)
# │   │   │       ├── 0 (T5LayerSelfAttention)
# │   │   │       │   ├── SelfAttention (T5Attention)
# │   │   │       │   │   ├── q,k,v,o(Linear) weight:[512, 512]
# │   │   │       │   │   └── relative_attention_bias (Embedding) weight:[32, 8]
# │   │   │       │   └── layer_norm (T5LayerNorm) weight:[512]
# │   │   │       └── 1 (T5LayerFF)
# │   │   │           ├── DenseReluDense (T5DenseActDense)
# │   │   │           │   ├── wi (Linear) weight:[2048, 512]
# │   │   │           │   └── wo (Linear) weight:[512, 2048]
# │   │   │           └── layer_norm (T5LayerNorm) weight:[512]
# │   │   └── 1-5(T5Block)
# │   │       └── layer (ModuleList)
# │   │           ├── 0 (T5LayerSelfAttention)
# │   │           │   ├── SelfAttention (T5Attention)
# │   │           │   │   └── q,k,v,o(Linear) weight:[512, 512]
# │   │           │   └── layer_norm (T5LayerNorm) weight:[512]
# │   │           └── 1 (T5LayerFF)
# │   │               ├── DenseReluDense (T5DenseActDense)
# │   │               │   ├── wi (Linear) weight:[2048, 512]
# │   │               │   └── wo (Linear) weight:[512, 2048]
# │   │               └── layer_norm (T5LayerNorm) weight:[512]
# │   ├── final_layer_norm (T5LayerNorm) weight:[512]
# │   └── soft_prompt_layer (SoftPromptLayer) soft_embeds:[10, 512]
# └── decoder (T5Stack)
#     ├── embed_tokens (Embedding) weight:[32128, 512]
#     ├── block (ModuleList)
#     │   ├── 0 (T5Block)
#     │   │   └── layer (ModuleList)
#     │   │       ├── 0 (T5LayerSelfAttention)
#     │   │       │   ├── SelfAttention (T5Attention)
#     │   │       │   │   ├── q,k,v,o(Linear) weight:[512, 512]
#     │   │       │   │   └── relative_attention_bias (Embedding) weight:[32, 8]
#     │   │       │   └── layer_norm (T5LayerNorm) weight:[512]
#     │   │       ├── 1 (T5LayerCrossAttention)
#     │   │       │   ├── EncDecAttention (T5Attention)
#     │   │       │   │   └── q,k,v,o(Linear) weight:[512, 512]
#     │   │       │   └── layer_norm (T5LayerNorm) weight:[512]
#     │   │       └── 2 (T5LayerFF)
#     │   │           ├── DenseReluDense (T5DenseActDense)
#     │   │           │   ├── wi (Linear) weight:[2048, 512]
#     │   │           │   └── wo (Linear) weight:[512, 2048]
#     │   │           └── layer_norm (T5LayerNorm) weight:[512]
#     │   └── 1-5(T5Block)
#     │       └── layer (ModuleList)
#     │           ├── 0 (T5LayerSelfAttention)
#     │           │   ├── SelfAttention (T5Attention)
#     │           │   │   └── q,k,v,o(Linear) weight:[512, 512]
#     │           │   └── layer_norm (T5LayerNorm) weight:[512]
#     │           ├── 1 (T5LayerCrossAttention)
#     │           │   ├── EncDecAttention (T5Attention)
#     │           │   │   └── q,k,v,o(Linear) weight:[512, 512]
#     │           │   └── layer_norm (T5LayerNorm) weight:[512]
#     │           └── 2 (T5LayerFF)
#     │               ├── DenseReluDense (T5DenseActDense)
#     │               │   ├── wi (Linear) weight:[2048, 512]
#     │               │   └── wo (Linear) weight:[512, 2048]
#     │               └── layer_norm (T5LayerNorm) weight:[512]
#     └── final_layer_norm (T5LayerNorm) weight:[512]
# [INFO|(OpenDelta)basemodel:698]2023-11-11 03:02:54,119 >> Trainable Ratio: 5120/60511744=0.008461%
# [INFO|(OpenDelta)basemodel:700]2023-11-11 03:02:54,120 >> Delta Parameter Ratio: 5120/60511744=0.008461%
# [INFO|(OpenDelta)basemodel:702]2023-11-11 03:02:54,121 >> Static Memory 1.02 GB, Max Memory 4.66 GB

# %%
train_results = train_model(soft_prompt_model.backbone_model)
# Out:
#        train_loss  valid_acc
# epoch
# 0        2.135413    0.84248
# 1        0.207845    0.85756
# 2        0.195598    0.85908
# 3        0.194045    0.86236
# 4        0.187535    0.85960
# 5        0.190711    0.85936
# 6        0.188096    0.85820
# 7        0.187610    0.86352
# 8        0.186248    0.84764
# 9        0.187408    0.86904

# %%
best_score = pd.DataFrame(train_results)['valid_acc'].max() * 100
total_params = sum(p.numel() for p in soft_prompt_model.parameters())
print(f"Number of parameters: {total_params}")
print('Best model preformance is: %%%.1f' % best_score)
# Out:
# Number of parameters: 5120
# Best model preformance is: %86.9

# %% [markdown]
# ### Fine-Tuning With N_SOFT_PROMPTS = 1

# %%
N_SOFT_PROMPT_TOKENS = 1

model = T5ForConditionalGeneration.from_pretrained(BASE_MODEL_NAME)
tokenizer = T5TokenizerFast.from_pretrained(BASE_MODEL_NAME)

soft_prompt_model = SoftPromptModel(backbone_model=model, soft_token_num=N_SOFT_PROMPT_TOKENS)

soft_prompt_model = soft_prompt_model.to(DEVICE)


optimizer = torch.optim.AdamW(soft_prompt_model.parameters(), lr=LEARNING_RATE)
compute_metrics = accuracy_score

# %%
soft_prompt_model.freeze_module(exclude=['deltas'])

soft_prompt_model.log()
# Out:
# root
# ├── shared(Embedding),lm_head(Linear) weight:[32128, 512]
# ├── encoder (T5Stack)
# │   ├── embed_tokens (Embedding) weight:[32128, 512]
# │   ├── block (ModuleList)
# │   │   ├── 0 (T5Block)
# │   │   │   └── layer (ModuleList)
# │   │   │       ├── 0 (T5LayerSelfAttention)
# │   │   │       │   ├── SelfAttention (T5Attention)
# │   │   │       │   │   ├── q,k,v,o(Linear) weight:[512, 512]
# │   │   │       │   │   └── relative_attention_bias (Embedding) weight:[32, 8]
# │   │   │       │   └── layer_norm (T5LayerNorm) weight:[512]
# │   │   │       └── 1 (T5LayerFF)
# │   │   │           ├── DenseReluDense (T5DenseActDense)
# │   │   │           │   ├── wi (Linear) weight:[2048, 512]
# │   │   │           │   └── wo (Linear) weight:[512, 2048]
# │   │   │           └── layer_norm (T5LayerNorm) weight:[512]
# │   │   └── 1-5(T5Block)
# │   │       └── layer (ModuleList)
# │   │           ├── 0 (T5LayerSelfAttention)
# │   │           │   ├── SelfAttention (T5Attention)
# │   │           │   │   └── q,k,v,o(Linear) weight:[512, 512]
# │   │           │   └── layer_norm (T5LayerNorm) weight:[512]
# │   │           └── 1 (T5LayerFF)
# │   │               ├── DenseReluDense (T5DenseActDense)
# │   │               │   ├── wi (Linear) weight:[2048, 512]
# │   │               │   └── wo (Linear) weight:[512, 2048]
# │   │               └── layer_norm (T5LayerNorm) weight:[512]
# │   ├── final_layer_norm (T5LayerNorm) weight:[512]
# │   └── soft_prompt_layer (SoftPromptLayer) soft_embeds:[1, 512]
# └── decoder (T5Stack)
#     ├── embed_tokens (Embedding) weight:[32128, 512]
#     ├── block (ModuleList)
#     │   ├── 0 (T5Block)
#     │   │   └── layer (ModuleList)
#     │   │       ├── 0 (T5LayerSelfAttention)
#     │   │       │   ├── SelfAttention (T5Attention)
#     │   │       │   │   ├── q,k,v,o(Linear) weight:[512, 512]
#     │   │       │   │   └── relative_attention_bias (Embedding) weight:[32, 8]
#     │   │       │   └── layer_norm (T5LayerNorm) weight:[512]
#     │   │       ├── 1 (T5LayerCrossAttention)
#     │   │       │   ├── EncDecAttention (T5Attention)
#     │   │       │   │   └── q,k,v,o(Linear) weight:[512, 512]
#     │   │       │   └── layer_norm (T5LayerNorm) weight:[512]
#     │   │       └── 2 (T5LayerFF)
#     │   │           ├── DenseReluDense (T5DenseActDense)
#     │   │           │   ├── wi (Linear) weight:[2048, 512]
#     │   │           │   └── wo (Linear) weight:[512, 2048]
#     │   │           └── layer_norm (T5LayerNorm) weight:[512]
#     │   └── 1-5(T5Block)
#     │       └── layer (ModuleList)
#     │           ├── 0 (T5LayerSelfAttention)
#     │           │   ├── SelfAttention (T5Attention)
#     │           │   │   └── q,k,v,o(Linear) weight:[512, 512]
#     │           │   └── layer_norm (T5LayerNorm) weight:[512]
#     │           ├── 1 (T5LayerCrossAttention)
#     │           │   ├── EncDecAttention (T5Attention)
#     │           │   │   └── q,k,v,o(Linear) weight:[512, 512]
#     │           │   └── layer_norm (T5LayerNorm) weight:[512]
#     │           └── 2 (T5LayerFF)
#     │               ├── DenseReluDense (T5DenseActDense)
#     │               │   ├── wi (Linear) weight:[2048, 512]
#     │               │   └── wo (Linear) weight:[512, 2048]
#     │               └── layer_norm (T5LayerNorm) weight:[512]
#     └── final_layer_norm (T5LayerNorm) weight:[512]
# [INFO|(OpenDelta)basemodel:698]2023-11-11 04:01:28,905 >> Trainable Ratio: 512/60507136=0.000846%
# [INFO|(OpenDelta)basemodel:700]2023-11-11 04:01:28,906 >> Delta Parameter Ratio: 512/60507136=0.000846%
# [INFO|(OpenDelta)basemodel:702]2023-11-11 04:01:28,906 >> Static Memory 0.68 GB, Max Memory 4.66 GB

# %%
train_results_spn1 = train_model(soft_prompt_model.backbone_model)
# Out:
#        train_loss  valid_acc
# epoch
# 0        7.872413    0.81460
# 1        0.414011    0.84052
# 2        0.363189    0.84732
# 3        0.354426    0.84736
# 4        0.360688    0.84736
# 5        0.367721    0.84464
# 6        0.379009    0.84204
# 7        0.401653    0.84496
# 8        0.442355    0.84412
# 9        0.463554    0.84260

# %%
best_score = pd.DataFrame(train_results_spn1)['valid_acc'].max() * 100
total_params = sum(p.numel() for p in soft_prompt_model.parameters())
print(f"Number of parameters: {total_params}")
print('Best model preformance is: %%%.1f' % best_score)
# Out:
# Number of parameters: 512
# Best model preformance is: %84.7
